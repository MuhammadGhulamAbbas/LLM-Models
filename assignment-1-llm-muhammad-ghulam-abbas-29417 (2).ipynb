# %%
# !pip install tiktoken transformers_stream_generator einops optimum  auto-gptq

# %% [markdown]
# # 1.1.8B Q4 Qwen
# #

# %%
# !pip install tiktoken
# !pip install einops transformers_stream_generator
# !pip install tiktoken transformers_stream_generator einops optimum  auto-gptq

from transformers import AutoModelForCausalLM, AutoTokenizer
import textwrap

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-1_8B-Chat", trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-1_8B-Chat", trust_remote_code=True).eval()

email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

prompt_summarize = f"""
Summarize the following email:

Email:
```{email}```
"""
response_summarize, history = model.chat(tokenizer, prompt_summarize, history=None)
print("Summarization:\n", textwrap.fill(response_summarize, width=80))
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.7/453.7 kB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 72.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 88.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.1 MB/s eta 0:00:00
# ...
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...
# model-00001-of-00002.safetensors:  35%|###4      | 713M/2.04G [00:00<?, ?B/s]
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import textwrap

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-1_8B-Chat", trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-1_8B-Chat", trust_remote_code=True).eval()

email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

prompt_qa = f"""
Answer the following questions based on the email:

Email:
```{email}```

Questions:
1. What was the reason for the customer's disappointment with WidgetCorp?
2. How did WidgetCorp's customer service respond to the customer's inquiries about the late delivery?
"""
response_qa, history = model.chat(tokenizer, prompt_qa, history=None)
print("\nQuestion Answering:\n", textwrap.fill(response_qa, width=80))
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Question Answering:
#  1. The reason for the customer's disappointment with WidgetCorp is mentioned in
# the email, which states that the SuperWidget did not arrive on time.   2. The
# customer service response in the email mentions that the customer tried to
# contact the company multiple times for an explanation and to expedite the
# delivery, but their calls and emails went unanswered. They also express that
# they are considering past purchases from WidgetCorp in the future.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import textwrap

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-1_8B-Chat", trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-1_8B-Chat", trust_remote_code=True).eval()

email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

prompt_ner = f"""
Identify the named entities in the following email and categorize them as 'Person', 'Date', 'Product', 'Order Number':

Email:
```{email}```
"""
response_ner, history = model.chat(tokenizer, prompt_ner, history=None)
print("\nNamed Entity Recognition (NER):\n", textwrap.fill(response_ner, width=80))
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Named Entity Recognition (NER):
#  The named entities in the email are:  - Person: Jane Doe - Date: March 15th
# (Emily's birthday) - Product: SuperWidget - Order Number: Order #98765  Note:
# The email contains two products - "SuperWidget" and "Birthday Gift" - which can
# be categorized as products. However, the specific details of these products are
# not provided in the email.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import textwrap

# Load the model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-1_8B-Chat", trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-1_8B-Chat", trust_remote_code=True).eval()

# Define the email
email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

# Translate from English to French
prompt_to_french = f"""
Translate the following email into French:

Email:
```{email}```
"""
response_french, history_french = model.chat(tokenizer, prompt_to_french, history=None)
print("Translation to French:\n", textwrap.fill(response_french, width=80))

# Translate from French back to English
email_french = response_french
prompt_to_english = f"""
Translate the following email from French back to English:

Email:
```{email_french}```
"""
response_english, history_english = model.chat(tokenizer, prompt_to_english, history=None)
print("Translation back to English:\n", textwrap.fill(response_english, width=80))
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Translation to French:
#  Message :   Bonjour widgetcorp, je vais exprimer ma grande déçu par votre
# service concernant mon dernier commande (numéro de commande #98765). J'ai choisi
# le produit "SuperWidget" comme un present pour ma DAUGHTER Emily, qui a dîné le
# 15 mars. malgré l'annonce sur votre site promise de la livraison en trois jours,
# le produit arrive seulement hier, tout en omettant ta fête. J'ai effectué
# plusieurs répétitions à l'客户服务 pour expliquer ce conflit et加速 la livraison, mais
# sans success. Mon téléphone et mon e-mail ont été ignorés, leaving moi dans une
# situation difficile avec aucun cadeau pour Emily's journée spéciale. Cette
# expérience me rend triste et je suis réfléchissant à des achats à partir du
# widgetcorp à未es. Je attend une réponse prompte et une assurance que这样的 latence
# ne se produise plus au futures. Cordialement, Jane Doe
# Translation back to English:
# ...

# %% [markdown]
# # 2.Phi-3.5-instruct

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Set default device to CUDA
torch.set_default_device("cuda")

# Load the model and tokenizer
model = AutoModelForCausalLM.from_pretrained("microsoft/Phi-3.5-mini-instruct", torch_dtype="auto", trust_remote_code=True).eval()
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3.5-mini-instruct", trust_remote_code=True)

# Define the email for summarization
email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

# Prepare the prompt for summarization
prompt = f"Summarize the following email:\n\nEmail:\n```{email}```"

# Prepare inputs
inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

# Generate summary
outputs = model.generate(**inputs, max_new_tokens=50)  # Adjust as needed

# Print the decoded summary
summary = tokenizer.decode(outputs[0], skip_special_tokens=True)
print("Summary:", summary)
# Out:
# config.json:   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Set default device to CUDA
torch.set_default_device("cuda")

# Load the model and tokenizer
model = AutoModelForCausalLM.from_pretrained("microsoft/Phi-3.5-mini-instruct", torch_dtype="auto", trust_remote_code=True).eval()
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3.5-mini-instruct", trust_remote_code=True)


# Define the email
email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

# Define the prompt for question answering
prompt_qa = f"""
Answer the following questions based on the email:

Email:
```{email}```

Questions:
1. What was the reason for the customer's disappointment with WidgetCorp?
2. How did WidgetCorp's customer service respond to the customer's inquiries about the late delivery?
"""

# Prepare inputs
inputs = tokenizer(prompt_qa, return_tensors="pt").to("cuda")

# Generate the response using the model
outputs = model.generate(**inputs, max_new_tokens=300)

# Decode and print the response
response_qa = tokenizer.decode(outputs[0], skip_special_tokens=True)
print("\nQuestion Answering:\n", response_qa)
# Out:
# config.json:   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import textwrap

# Set default device to CUDA
torch.set_default_device("cuda")

# Load the model and tokenizer
model = AutoModelForCausalLM.from_pretrained("microsoft/Phi-3.5-mini-instruct", torch_dtype="auto", trust_remote_code=True).eval()
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3.5-mini-instruct", trust_remote_code=True)

# Define the email
email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

# Define the prompt for named entity recognition (NER)
prompt_ner = f"""
Identify the named entities in the following email and categorize them as 'Person', 'Date', 'Product', 'Order Number':

Email:
```{email}```
"""

# Prepare inputs
inputs = tokenizer(prompt_ner, return_tensors="pt").to("cuda")

# Generate the response using the model
outputs = model.generate(**inputs, max_new_tokens=300)

# Decode the response
response_ner = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Print the result with text wrapping
print("\nNamed Entity Recognition (NER):\n")
print(textwrap.fill(response_ner, width=80))
# Out:
# config.json:   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import textwrap

# Set default device to CUDA
torch.set_default_device("cuda")

# Load the model and tokenizer
model = AutoModelForCausalLM.from_pretrained("microsoft/Phi-3.5-mini-instruct", torch_dtype="auto", trust_remote_code=True).eval()
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3.5-mini-instruct", trust_remote_code=True)

# Define the email
email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

# Translate from English to French
prompt_to_french = f"""
Translate the following email into French:

Email:
```{email}```
"""

# Prepare inputs for translation to French
inputs_french = tokenizer(prompt_to_french, return_tensors="pt").to("cuda")

# Generate the response for French translation
outputs_french = model.generate(**inputs_french, max_new_tokens=300)

# Decode and print the translation to French
response_french = tokenizer.decode(outputs_french[0], skip_special_tokens=True)
print("Translation to French:\n", textwrap.fill(response_french, width=80))

# Translate from French back to English
prompt_to_english = f"""
Translate the following email from French back to English:

Email:
```{response_french}```
"""

# Prepare inputs for translation back to English
inputs_english = tokenizer(prompt_to_english, return_tensors="pt").to("cuda")

# Generate the response for translation back to English
outputs_english = model.generate(**inputs_english, max_new_tokens=300)

# Decode and print the translation back to English
response_english = tokenizer.decode(outputs_english[0], skip_special_tokens=True)
print("Translation back to English:\n", textwrap.fill(response_english, width=80))
# Out:
# config.json:   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# ...

# %% [markdown]
# # 3.Llama-3.1-8B-instruct

# %%
# !pip install packaging ninja
# !pip install accelerate
# !pip install huggingface_hub
# !python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('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')"
# !pip install torch

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.4.0
# 12.3
# True
# Tesla P100-PCIE-16GB

# %%
# !pip install ipywidgets

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    #torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Define the correct model ID for the Meta-Llama-3.1-8B-Instruct model
model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"

# Load the tokenizer for the model. This converts text into token IDs that the model can process.
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Load the model. Using torch.float16 for faster computation and specifying device_map="auto" to automatically distribute the model across available devices (GPU/CPU).
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,  # Using float16 for better performance on GPUs
    device_map="auto",          # Automatically map the model to available hardware (CPU/GPU)
)

# Define the email to summarize
email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

# Prepare the prompt that asks the model to summarize the given email
prompt = f"Summarize the following email:\n\nEmail:\n```{email}```"

# Tokenize the prompt. This converts the text into a format that the model understands (i.e., into token IDs).
inputs = tokenizer(prompt, return_tensors="pt").to("cuda" if torch.cuda.is_available() else "cpu")

# Generate the summary using the model. The `max_new_tokens` parameter limits how long the summary can be.
outputs = model.generate(**inputs, max_new_tokens=50)

# Decode the generated token IDs back into text (the summary).
summary = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Print the generated summary.
print("Summary:", summary)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Summary: Summarize the following email:
#
# Email:
# ```
# Dear WidgetCorp,
# I am writing to express my deep disappointment with your service regarding my recent order (Order #98765).
# I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th.
# Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.
#
# I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail.
# My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.
#
# This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp.
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Define the model ID for the Meta-Llama-3.1-8B-Instruct model
model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,  # Use float16 for faster performance on GPUs
    device_map="auto",          # Automatically map the model to available hardware (CPU/GPU)
)

# Define the email to be used for question answering
email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

# Define the prompt for question answering
prompt_qa = f"""
Answer the following questions based on the email:

Email:
```{email}```

Questions:
1. What was the reason for the customer's disappointment with WidgetCorp?
2. How did WidgetCorp's customer service respond to the customer's inquiries about the late delivery?
"""

# Tokenize the prompt for the QA task
inputs = tokenizer(prompt_qa, return_tensors="pt").to("cuda" if torch.cuda.is_available() else "cpu")

# Generate the answers using the model
outputs = model.generate(**inputs, max_new_tokens=150)

# Decode the generated token IDs back into text (the answers)
answers = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Print the generated answers
print("Question and Answer Output:\n")
print(answers)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Question and Answer Output:
#
#
# Answer the following questions based on the email:
#
# Email:
# ```
# Dear WidgetCorp,
# I am writing to express my deep disappointment with your service regarding my recent order (Order #98765).
# I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th.
# Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.
#
# I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail.
# My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.
#
# This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp.
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import textwrap

# Define the model ID for the Meta-Llama-3.1-8B-Instruct model
model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,  # Use float16 for faster performance on GPUs
    device_map="auto",          # Automatically map the model to available hardware (CPU/GPU)
)

# Define the email for named entity recognition (NER)
email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

# Define the prompt for Named Entity Recognition (NER)
prompt_ner = f"""
Identify the named entities in the following email and categorize them as 'Person', 'Date', 'Product', 'Order Number':

Email:
```{email}```
"""

# Prepare inputs for the NER task
inputs = tokenizer(prompt_ner, return_tensors="pt").to("cuda" if torch.cuda.is_available() else "cpu")

# Generate the response using the model with optimizations for speed
# Reduce max_new_tokens to avoid unnecessary long generations
outputs = model.generate(**inputs, max_new_tokens=100, do_sample=False)

# Decode the generated token IDs back into text (the NER response)
response_ner = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Print the result with text wrapping for better readability
print("\nNamed Entity Recognition (NER):\n")
print(textwrap.fill(response_ner, width=80))
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:567: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:572: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Named Entity Recognition (NER):
#
#  Identify the named entities in the following email and categorize them as
# 'Person', 'Date', 'Product', 'Order Number':  Email: ``` Dear WidgetCorp, I am
# ...

# %%
# !pip install packaging ninja
# !pip install accelerate
# !pip install huggingface_hub
# !python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('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')"
# !pip install torch

from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import textwrap

# Define the model ID for the Meta-Llama-3.1-8B-Instruct model
model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,  # Use float16 for faster performance on GPUs
    device_map="auto",          # Automatically map the model to available hardware (CPU/GPU)
)

# Define the email text for translation
email = '''
Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). 
I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. 
Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely.

I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. 
My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day.

This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. 
I expect a prompt explanation and an assurance that such delays will not occur in the future.

Sincerely, Jane Doe
'''

# Step 1: Translate from English to French
prompt_to_french = f"""
Translate the following email into French:

Email:
```{email}```
"""

# Prepare inputs for translation to French
inputs_french = tokenizer(prompt_to_french, return_tensors="pt").to("cuda" if torch.cuda.is_available() else "cpu")

# Generate the response for the French translation with optimizations
outputs_french = model.generate(**inputs_french, max_new_tokens=100, do_sample=False)

# Decode the response (French translation)
response_french = tokenizer.decode(outputs_french[0], skip_special_tokens=True)

# Print the French translation with text wrapping for readability
print("Translation to French:\n", textwrap.fill(response_french, width=80))

# Step 2: Translate from French back to English
prompt_to_english = f"""
Translate the following email from French back to English:

Email:
```{response_french}```
"""

# Prepare inputs for translation back to English
inputs_english = tokenizer(prompt_to_english, return_tensors="pt").to("cuda" if torch.cuda.is_available() else "cpu")

# Generate the response for the English translation with optimizations
outputs_english = model.generate(**inputs_english, max_new_tokens=100, do_sample=False)

# Decode the response (translation back to English)
response_english = tokenizer.decode(outputs_english[0], skip_special_tokens=True)

# Print the English translation with text wrapping for readability
print("\nTranslation back to English:\n", textwrap.fill(response_english, width=80))
# Out:
# ...
# tokenizer_config.json:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# ...

# %% [markdown]
# # Summarization
# Qwen Model (4): Solid summary with good relevance but could be slightly more concise.
#
# Phi-3.5-instruct (3): Clear but less concise and relevant; needs more focus.
#
# Llama-3.1-8B-instruct (4): Effective balance of detail and clarity, but can improve in brevity.
#
# Mistral-instruct (5): Outstanding in conciseness, relevance, and clarity; the best choice for summarization.

# %% [markdown]
# # Question Answering
# Qwen Model (4): Provides accurate answers with good relevance but could benefit from more detail in certain areas.
#
# Phi-3.5-instruct (3): Struggles with accuracy and relevance; answers lack clarity and need significant improvements.
#
# Llama-3.1-8B-instruct (4): Delivers strong, relevant answers with good clarity, but minor adjustments in detail could enhance performance.
#
# Mistral-instruct (5): Excels in accuracy, relevance, and clarity; consistently provides comprehensive and well-structured answers.

# %% [markdown]
# # Named Entity Recognition (NER):
# Qwen Model (4): Accurately identifies key entities with good relevance, but could benefit from including more detailed context and additional entities.
#
# Phi-3.5-instruct (3): Struggles with accuracy and relevance; fails to capture some key entities and lacks clarity, requiring significant improvements.
#
# Llama-3.1-8B-instruct (4): Delivers strong identification of entities with good clarity, though minor adjustments in detail and categorization could enhance its performance.
#
# Mistral-instruct (5): Excels in accuracy, relevance, and clarity; consistently provides a comprehensive and well-structured identification of all relevant entities.

# %% [markdown]
# # Translation (English to French to English)
# Qwen Model (2): Produces translations that often misrepresent the original message, leading to confusion. The fluency of the back-translation is poor, and terminology is inconsistent, resulting in a lack of coherence and clarity.
#
# Phi-3.5-instruct (3): Offers moderate translation quality with noticeable accuracy issues. Key elements are sometimes lost, and the overall clarity of the back-translation is lacking, indicating a need for significant improvements in fidelity and expression.
#
# Llama-3.1-8B-instruct (4): Provides solid translations that effectively convey the original message with good clarity. While it captures most details accurately, there are minor areas for enhancement in terminology consistency and overall fluency.
#
# Mistral-instruct (5): Excels in delivering highly accurate and fluent translations. It consistently offers a comprehensive interpretation of the original text, maintaining clarity, consistency, and appropriate tone throughout, making it the gold standard for translation quality.

# %% [markdown]
# # Model Performance Summary
#
# 1.Qwen Model
#
# Summarization: 4
#
# Question Answering: 4
#
# Named Entity Recognition (NER): 4
#
# Translation (English to French to English): 2
#
# https://huggingface.co/Qwen/Qwen-1_8B-Chat
#
# 2.Phi-3.5-instruct
#
# Summarization: 3
#
# Question Answering: 3
#
# Named Entity Recognition (NER): 3
#
# Translation (English to French to English): 3
#
# https://huggingface.co/microsoft/Phi-3.5-mini-instruct
#
# 3.Llama-3.1-8B-instruct
#
# Summarization: 4
#
# Question Answering: 4
#
# Named Entity Recognition (NER): 4
#
# Translation (English to French to English): 4
#
# https://huggingface.co/meta-llama/Meta-Llama-3.1-8B-Instruct
#
# 4.Mistral-instruct
#
# Summarization: 5
#
# Question Answering: 5
#
# Named Entity Recognition (NER): 5
#
# Translation (English to French to English): 5
#
# https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2
#
# Conclusion
#
# Mistral-instruct is the top-performing model across all tasks, demonstrating superior accuracy, relevance, and clarity. Llama-3.1-8B-instruct and Qwen Model show solid performance, while Phi-3.5-instruct generally underperforms.
